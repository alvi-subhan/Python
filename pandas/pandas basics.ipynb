# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#date format is ISO i.e Y/months.day
dates = pd.date_range('20130101', periods=6) #periods=date end point
dates #D represnts day
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates[0]
type(dates[0])
# Out:
# pandas._libs.tslib.Timestamp

# %%
lis=list("hjklmn")
print(lis)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
# ['h', 'j', 'k', 'l', 'm', 'n']
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2013-01-01</th>
#       <td>-1.222135</td>
#       <td>-0.207597</td>
#       <td>-0.170088</td>
#       <td>0.525815</td>
#     </tr>
#     <tr>
#       <th>2013-01-02</th>
#       <td>0.202917</td>
#       <td>0.320850</td>
#       <td>-0.923694</td>
#       <td>0.779013</td>
#     </tr>
#     <tr>
#       <th>2013-01-03</th>
#       <td>-0.285526</td>
#       <td>0.039878</td>
#       <td>0.674885</td>
#       <td>-1.824331</td>
#     </tr>
#     <tr>
# ...

# %%
liss=["id","name","course","attendance","contact","NIC"]
datess= pd.date_range('20180101', periods=31) #periods=date end point

df = pd.DataFrame(np.random.randn(31,6), index=datess, columns=liss)
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>course</th>
#       <th>attendance</th>
#       <th>contact</th>
#       <th>NIC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018-01-01</th>
#       <td>-0.892039</td>
#       <td>1.483537</td>
#       <td>-0.046926</td>
#       <td>-0.163745</td>
#       <td>-0.182035</td>
#       <td>0.463687</td>
#     </tr>
#     <tr>
#       <th>2018-01-02</th>
#       <td>0.552074</td>
#       <td>-0.640243</td>
#       <td>0.927259</td>
#       <td>-0.590014</td>
#       <td>1.476754</td>
#       <td>0.484930</td>
#     </tr>
#     <tr>
#       <th>2018-01-03</th>
# ...

# %%
df[:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>course</th>
#       <th>attendance</th>
#       <th>contact</th>
#       <th>NIC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018-01-01</th>
#       <td>-0.892039</td>
#       <td>1.483537</td>
#       <td>-0.046926</td>
#       <td>-0.163745</td>
#       <td>-0.182035</td>
#       <td>0.463687</td>
#     </tr>
#     <tr>
#       <th>2018-01-02</th>
#       <td>0.552074</td>
#       <td>-0.640243</td>
#       <td>0.927259</td>
#       <td>-0.590014</td>
#       <td>1.476754</td>
#       <td>0.484930</td>
#     </tr>
#     <tr>
#       <th>2018-01-03</th>
# ...

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'), #generate 3 4 times
                    'E' : pd.Categorical(["test","train","test","train"]),
                    'F' : 'foo' })
df2

#dic se ye faida hoga k ab humein coloumns k naam define nae krne parenge
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>train</td>
#       <td>foo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2013-01-02</td>
#       <td>1.0</td>
#       <td>3</td>
#       <td>test</td>
# ...

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
main_url="https://api.cryptonator.com/api/full/"


import urllib.parse, requests,json
from matplotlib import pyplot as plt


main_url="https://api.cryptonator.com/api/full/"
add="btc-usd"

url=main_url+add
print(url)
json_data=requests.get(url).json()

#print(json_data["ticker"]["base"])

print(json_data["ticker"]["markets"][0])

xx=json_data["ticker"]["markets"]
print (xx)
# Out:
# https://api.cryptonator.com/api/full/btc-usd
# {'market': 'BitFinex', 'price': '8191.60000000', 'volume': 97737.59164907}
# [{'market': 'BitFinex', 'price': '8191.60000000', 'volume': 97737.59164907}, {'market': 'Bitstamp', 'price': '8211.04000000', 'volume': 23688.41650507}, {'market': 'Bittrex', 'price': '8160.00000000', 'volume': 7776.46199686}, {'market': 'C-Cex', 'price': '9087.71250000', 'volume': 2.93783661}, {'market': 'Cex.io', 'price': '8393.30000000', 'volume': 2675.67958546}, {'market': 'Exmo', 'price': '8750.00000000', 'volume': 1915.44843884}, {'market': 'Hitbtc', 'price': '8550.00000000', 'volume': 7647.4}, {'market': 'Kraken', 'price': '8193.50000000', 'volume': 20695.58367522}, {'market': 'Livecoin', 'price': '8495.00000000', 'volume': 1240.61333779}, {'market': 'Poloniex', 'price': '8171.57880298', 'volume': 7557.1306197}, {'market': 'wexnz', 'price': '8350.01100000', 'volume': 1336.41663}, {'market': 'YoBit', 'price': '8682.04289996', 'volume': 221.99895198}]

# %%
#print(2)
da=pd.DataFrame(xx)
da
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market</th>
#       <th>price</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BitFinex</td>
#       <td>8191.60000000</td>
#       <td>97737.591649</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bitstamp</td>
#       <td>8211.04000000</td>
#       <td>23688.416505</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bittrex</td>
#       <td>8160.00000000</td>
#       <td>7776.461997</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C-Cex</td>
#       <td>9087.71250000</td>
#       <td>2.937837</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
da.dtypes
# Out:
# market     object
# price      object
# volume    float64
# dtype: object

# %%
da.head(6)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>market</th>
#       <th>price</th>
#       <th>volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BitFinex</td>
#       <td>8191.60000000</td>
#       <td>97737.591649</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bitstamp</td>
#       <td>8211.04000000</td>
#       <td>23688.416505</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Bittrex</td>
#       <td>8160.00000000</td>
#       <td>7776.461997</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C-Cex</td>
#       <td>9087.71250000</td>
#       <td>2.937837</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
len(da.index)
# Out:
# 12

# %%
z=da.values[:,:2]
z
# Out:
# array([['BitFinex', '8191.60000000'],
#        ['Bitstamp', '8211.04000000'],
#        ['Bittrex', '8160.00000000'],
#        ['C-Cex', '9087.71250000'],
#        ['Cex.io', '8393.30000000'],
#        ['Exmo', '8750.00000000'],
#        ['Hitbtc', '8550.00000000'],
#        ['Kraken', '8193.50000000'],
#        ['Livecoin', '8495.00000000'],
#        ['Poloniex', '8171.57880298'],
#        ['wexnz', '8350.01100000'],
#        ['YoBit', '8682.04289996']], dtype=object)

# %%
z[1,1]
# Out:
# '8211.04000000'

# %%
zz=z[[1,11]]
zz
# Out:
# array([['Bitstamp', '8211.04000000'],
#        ['YoBit', '8682.04289996']], dtype=object)

# %%
3
